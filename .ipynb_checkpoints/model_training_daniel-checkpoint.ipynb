# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X = np.load("data_np/x.npy",allow_pickle=True)

# %%
y=np.load("data_np/y.npy")

# %%
import pandas as pd

# %%
X = pd.DataFrame(X)

# %%
X
# Out:
#             0         1             2         3         4         5   \
# 0     0.548139  0.930388  8.193634e-07  0.657407  0.873510 -0.067983
# 1     0.573536  0.692016  5.064923e-07  0.660410  0.652108 -0.049131
# 2     0.821502  0.733739  4.509642e-07  0.910764  0.674695 -0.024163
# 3     0.217215  0.684824  4.849443e-07  0.338255  0.619847 -0.045516
# 4     0.230864  0.779946  4.564230e-07  0.288554  0.726251 -0.033165
# ...        ...       ...           ...       ...       ...       ...
# 8840  0.035649  0.842390  1.060834e-06  0.109344  0.841092 -0.029273
# 8841  0.599450  0.717768  9.143174e-07  0.665837  0.741676 -0.052994
# 8842  0.191475  0.375166  7.227814e-07  0.281403  0.367547  0.000295
# 8843  0.218933  0.846389  9.186841e-07  0.299284  0.858845 -0.048820
# 8844  0.477316  0.621177  8.567137e-07  0.556614  0.624539 -0.035221
#
#             6         7         8         9   ...        53        54  \
# 0     0.727627  0.747707 -0.090616  0.644857  ... -0.052989  0.498861
# 1     0.721002  0.573792 -0.066285  0.688100  ... -0.035999  0.535491
# 2     0.965533  0.589727 -0.028153  0.944653  ... -0.024086  0.771659
# 3     0.413366  0.529438 -0.058334  0.350698  ... -0.026724  0.172721
# 4     0.302774  0.640968 -0.044318  0.235526  ... -0.030723  0.119446
# ...        ...       ...       ...       ...  ...       ...       ...
# 8840  0.195617  0.794139 -0.057849  0.270519  ... -0.058595  0.167533
# 8841  0.746193  0.729573 -0.084287  0.819168  ... -0.037397  0.738868
# 8842  0.359446  0.328222 -0.012380  0.432577  ... -0.039190  0.346903
# 8843  0.385640  0.828444 -0.078238  0.461841  ... -0.021586  0.426358
# 8844  0.643464  0.588638 -0.055673  0.716931  ... -0.022001  0.596666
#
#             55        56        57        58        59        60        61  \
# 0     0.479037 -0.078587  0.510385  0.400655 -0.089919  0.517950  0.331495
# 1     0.375336 -0.054846  0.542014  0.317661 -0.065047  0.545734  0.269621
# 2     0.405635 -0.036660  0.779212  0.349682 -0.040809  0.785382  0.303342
# 3     0.318204 -0.047341  0.178884  0.250578 -0.060364  0.180672  0.191315
# 4     0.523144 -0.041957  0.112325  0.478814 -0.045598  0.104014  0.440313
# ...        ...       ...       ...       ...       ...       ...       ...
# 8840  0.583305 -0.074227  0.232545  0.563399 -0.075342  0.282388  0.557658
# 8841  0.500467 -0.056969  0.793947  0.473735 -0.064245  0.843027  0.460117
# 8842  0.069406 -0.040955  0.411068  0.050482 -0.037992  0.465242  0.048872
# 8843  0.605378 -0.032019  0.488299  0.605097 -0.034193  0.534345  0.619182
# 8844  0.342657 -0.038924  0.653926  0.311578 -0.045359  0.705801  0.297850
#
#             62
# 0    -0.095870
# 1    -0.071029
# 2    -0.042630
# 3    -0.068345
# 4    -0.047405
# ...        ...
# 8840 -0.073489
# 8841 -0.066923
# 8842 -0.036696
# 8843 -0.033423
# 8844 -0.047579
#
# [8845 rows x 63 columns]

# %%
y = pd.Series(y)
y
# Out:
# 0       B
# 1       B
# 2       B
# 3       B
# 4       B
#        ..
# 8840    C
# 8841    C
# 8842    C
# 8843    C
# 8844    C
# Length: 8845, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC


models = {
    "SGD":SGDClassifier(average = True),
    "KNN_3":KNeighborsClassifier(3),
    "KNN_5":KNeighborsClassifier(5),
    "KNN_7":KNeighborsClassifier(7),
    "SVC": SVC(),
    "RandomForest": RandomForestClassifier(),
    "LogisticRegresion": LogisticRegression()
    
}

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
for model_tag, model in models.items():
    print(f"************{model_tag}************")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='micro')
    recall = recall_score(y_test, y_pred, average='micro')
    f1 = f1_score(y_test, y_pred, average='micro')
    
    print(f"Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1: {f1}")
# Out:
# ************SGD************
# Accuracy: 0.9886941775014132, Precision: 0.9886941775014132, Recall: 0.9886941775014132, F1: 0.9886941775014132
# ************KNN_3************
# Accuracy: 0.9960429621254946, Precision: 0.9960429621254946, Recall: 0.9960429621254946, F1: 0.9960429621254946
# ************KNN_5************
# Accuracy: 0.994912379875636, Precision: 0.994912379875636, Recall: 0.994912379875636, F1: 0.994912379875636
# ************KNN_7************
# Accuracy: 0.9932165065008479, Precision: 0.9932165065008479, Recall: 0.9932165065008479, F1: 0.9932165065008479
# ************SVC************
# Accuracy: 0.9932165065008479, Precision: 0.9932165065008479, Recall: 0.9932165065008479, F1: 0.9932165065008479
# ************RandomForest************
# Accuracy: 0.9954776710005653, Precision: 0.9954776710005653, Recall: 0.9954776710005653, F1: 0.9954776710005653
# ************LogisticRegresion************
# Accuracy: 0.9915206331260599, Precision: 0.9915206331260599, Recall: 0.9915206331260599, F1: 0.9915206331260599
# /home/iremirezdeganuza/miniconda3/envs/fproject/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
